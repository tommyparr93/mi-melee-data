# %% [markdown]
# ## Brainstorming Notebook for Using LLMs to Query PostgreSQL Database
#
# Input: Natural language prompt (e.g., "how many times did HTCP beat mathandsurf in 2022?")
# => Use LLM to generate SQL Query based on structure of database and retrieve results from PostgreSQL database
# => Use LLM to generate answer in natural language (e.g., "HTCP beat mathandsurf 3 times in 2022.")
#
# Commented out the cell below, but this could be one option for how we could connect to the PostgreSQL database you have hosted on Amazon Lightsail.

# %%
""" 
# Connect to the database
import psycopg2

# Database connection details
hostname = 'your_lightsail_hostname'
port = 5432
database = 'your_database_name'
username = 'your_username'
password = 'your_password'

# Connect to the database
db = psycopg2.connect(
    host=hostname,
    port=port,
    database=database,
    user=username,
    password=password
)
# Might be able to get around using psycopg2 with something like this---- Use SQLDatabase.from_uri() to connect to the database
db = SQLDatabase.from_uri(f"postgresql://{username}:{password}@{hostname}:{port}/{database}")
"""

# %%
# Load .env file
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.llms import OpenAI
from langchain.agents.agent_toolkits import SQLDatabaseToolkit
from langchain.agents import create_sql_agent

# Instantiate the OpenAI LLM model (temperature=0 means deterministic; verbose=True means print the output, note 
# we are using the LLM-version and not the chat version)
llm = OpenAI(temperature=0, verbose=True)

# Connect to the database. Using a toy dataset from https://github.com/BroccoliRaab/meleedb to play around with the idea.
db = SQLDatabase.from_uri("sqlite:///melee/static/data/meleedb.db",
                          include_tables=['melee_hitboxes', 'character_attributes'],
                          sample_rows_in_table_info=3)

print(db.table_info)
# Out:
# CREATE TABLE character_attributes (
# 	"dashAndRunAccelerationA" FLOAT,
# 	"bubbleRatio" INTEGER,
# 	friction FLOAT,
# 	"airMobilityB" FLOAT,
# 	"runAcceleration" INTEGER,
# 	"kirbyStarDamage" INTEGER,
# 	"numberOfJumps" INTEGER,
# 	"jumpHInitialVelocity" FLOAT,
# 	"walkAcceleration" FLOAT,
# 	"jab3Window?" INTEGER,
# 	"doubleJumpMomentum" FLOAT,
# 	"initialWalkVelocity" FLOAT,
# 	"jumpVInitialVelocity" FLOAT,
# 	gravity FLOAT,
# 	"walkMaximumVelocity" FLOAT,
# 	"maxAerialHVelocity" FLOAT,
# 	"iceTraction?" INTEGER,
# 	"walljumpVVelocity" FLOAT,
# 	"runAnimationScaling" FLOAT,
# 	"walljumpHVelocity" FLOAT,
# 	"jumpStartup" INTEGER,
# 	character VARCHAR,
# 	"rapidJabWindow" INTEGER,
# 	"victoryScreenWindowModelScaling" INTEGER,
# 	"dairLandingLag" INTEGER,
# 	weight INTEGER,
# 	"bairLandingLag" INTEGER,
# 	"ledgejumpHorizontalVelocity" INTEGER,
# 	"fairLandingLag" INTEGER,
# 	"shorthopVInitialVelocity" FLOAT,
# 	"cameraTargetZoomBone" INTEGER,
# 	"airJumpMultiplier" FLOAT,
# 	"normalLandingLag" INTEGER,
# 	"specialJumpAction" INTEGER,
# 	"itemThrowVelocity" INTEGER,
# 	"ledgejumpVertical" FLOAT,
# 	"dashAndRunAccelerationB" FLOAT,
# 	"airMobilityA" FLOAT,
# 	"midWalkPoint" FLOAT,
# 	"airFriction" FLOAT,
# 	"dashInitialVelocity" FLOAT,
# 	"modelScaling" FLOAT,
# 	"jumpHMaximumVelocity" FLOAT,
# 	"nairLandingLag" INTEGER,
# 	"?" INTEGER,
# 	"groundAirJumpMomentumMultiplier" FLOAT,
# 	"uairLandingLag" INTEGER,
# 	"turnDuration" INTEGER,
# 	"fastWalkMin" FLOAT,
# 	"fastFallTerminalVelocity" INTEGER,
# 	"shieldBreakInitialVelocity" FLOAT,
# 	"shieldSize" FLOAT,
# 	"jab2Window?" INTEGER,
# 	"walkAnimationSpeed" FLOAT,
# 	"terminalVelocity" FLOAT,
# 	"weightDepThrowSpeedFlags" INTEGER,
# 	"dashAndRunTerminalVelocity" FLOAT
# )
#
# /*
# 3 rows from character_attributes table:
# dashAndRunAccelerationA	bubbleRatio	friction	airMobilityB	runAcceleration	kirbyStarDamage	numberOfJumps	jumpHInitialVelocity	walkAcceleration	jab3Window?	doubleJumpMomentum	initialWalkVelocity	jumpVInitialVelocity	gravity	walkMaximumVelocity	maxAerialHVelocity	iceTraction?	walljumpVVelocity	runAnimationScaling	walljumpHVelocity	jumpStartup	character	rapidJabWindow	victoryScreenWindowModelScaling	dairLandingLag	weight	bairLandingLag	ledgejumpHorizontalVelocity	fairLandingLag	shorthopVInitialVelocity	cameraTargetZoomBone	airJumpMultiplier	normalLandingLag	specialJumpAction	itemThrowVelocity	ledgejumpVertical	dashAndRunAccelerationB	airMobilityA	midWalkPoint	airFriction	dashInitialVelocity	modelScaling	jumpHMaximumVelocity	nairLandingLag	?	groundAirJumpMomentumMultiplier	uairLandingLag	turnDuration	fastWalkMin	fastFallTerminalVelocity	shieldBreakInitialVelocity	shieldSize	jab2Window?	walkAnimationSpeed	terminalVelocity	weightDepThrowSpeedFlags	dashAndRunTerminalVelocity
# 0.064999997615814	7	0.090000003576279	0.18999999761581	30	10	6	0.69999998807907	0.10000000149012	0	0.0	0.15999999642372	1.6000000238419	0.064000003039837	0.69999998807907	1.3500000238419	1	1.6000000238419	1.3250000476837	1.2999999523163	5	Jigglypuff	0	16	30	60	20	1.1000000238419	20	1.0499999523163	5	0.0	4	0	0.89999997615814	1.7999999523163	0.019999999552965	0.090000003576279	0.43239998817444	0.050000000745058	1.3999999761581	0.93999999761581	1.3500000238419	20	0	1.0	20	4	0.68870669603348	1.6000000238419	10.0	13.125	24	0.17859999835491	1.2999999523163	150994944	1.1000000238419
# 0.059999998658895	10	0.059999998658895	0.019999999552965	30	15	2	1.0	0.0	24	1.0	0.15000000596046	2.4000000953674	0.08500000089407	1.6000000238419	0.89999997615814	1	2.4000000953674	1.3999999761581	1.2999999523163	4	Marth	5	24	32	87	24	1	15	1.5	21	0.87999999523163	4	0	1	2.4000000953674	0.0	0.029999999329448	0.62099999189377	0.0049999998882413	1.5	1.1499999761581	1.2000000476837	15	0	0.80000001192093	15	6	0.97750002145767	2.5	2.5	11.75	24	0.25299999117851	2.2000000476837	0	1.7999999523163
# 0.059999998658895	8.1999998092651	0.025000000372529	0.014999999664724	30	17	2	0.80000001192093	0.10000000149012	24	0.89999997615814	0.10000000149012	2.4000000953674	0.068999998271465	1.1000000238419	0.68000000715256	1	2.0999999046326	1.4500000476837	1.2999999523163	4	Luigi	0	22	18	100	15	1	25	1.3999999761581	5	0.89999997615814	4	0	1	2.0999999046326	0.019999999552965	0.025000000372529	0.43999999761581	0.0099999997764826	1.2999999523163	1.25	0.75	15	0	0.80000001192093	15	4	0.69999998807907	2	2.4000000953674	10.75	24	0.18000000715256	1.6000000238419	0	1.3400000333786
# */
#
#
# CREATE TABLE melee_hitboxes (
# 	"end" INTEGER,
# 	"bestShieldAdvantage" INTEGER,
# 	"minimumLag" INTEGER,
# 	bone INTEGER,
# 	"weightDepKb" INTEGER,
# 	damage INTEGER,
# 	"hitboxInteraction" INTEGER,
# 	element VARCHAR,
# 	shieldstun INTEGER,
# 	id INTEGER,
# 	guid INTEGER,
# 	"subactionIndex" INTEGER,
# 	y FLOAT,
# 	"groupId" INTEGER,
# 	z FLOAT,
# 	"baseKb" INTEGER,
# 	x FLOAT,
# 	angle INTEGER,
# 	move VARCHAR,
# 	"hitGrounded" VARCHAR,
# 	"totalFrames" INTEGER,
# 	size FLOAT,
# 	"subactionName" VARCHAR,
# 	"shieldDamage" INTEGER,
# 	start INTEGER,
# 	character VARCHAR,
# 	"hitAirborne" VARCHAR,
# 	sfx INTEGER,
# 	"kbGrowth" INTEGER,
# 	"landingLag" INTEGER,
# 	"autoCancelAfter" INTEGER,
# 	iasa INTEGER,
# 	"lcancelledLandingLag" INTEGER,
# 	"autoCancelBefore" INTEGER,
# 	"chargeFrame" INTEGER,
# 	"lcancelledShieldAdvantage" INTEGER,
# 	"missedLcancelShieldAdvantage" INTEGER,
# 	"earlyHitAutoCancelledShieldAdvantage" INTEGER,
# 	"lateHitAutoCancelledShieldAdvantage" INTEGER,
# 	"earlyHitIASACancelledShieldAdvantage" INTEGER,
# 	"lateHitIASACancelledShieldAdvantage" INTEGER,
# 	"earlyHitTotalFramesShieldAdvantage" INTEGER,
# 	"lateHitTotalFramesShieldAdvantage" INTEGER
# )
#
# /*
# 3 rows from melee_hitboxes table:
# end	bestShieldAdvantage	minimumLag	bone	weightDepKb	damage	hitboxInteraction	element	shieldstun	id	guid	subactionIndex	y	groupId	z	baseKb	x	angle	move	hitGrounded	totalFrames	size	subactionName	shieldDamage	start	character	hitAirborne	sfx	kbGrowth	landingLag	autoCancelAfter	iasa	lcancelledLandingLag	autoCancelBefore	chargeFrame	lcancelledShieldAdvantage	missedLcancelShieldAdvantage	earlyHitAutoCancelledShieldAdvantage	lateHitAutoCancelledShieldAdvantage	earlyHitIASACancelledShieldAdvantage	lateHitIASACancelledShieldAdvantage	earlyHitTotalFramesShieldAdvantage	lateHitTotalFramesShieldAdvantage
# 10	-56	59	44	40	4	3	normal	3	0	0	323	8.2352941176471	0	0.0	0	0.0	110	0x143	true	69	3.1372549019608	PlyKirby5K_Share_ACTION_SpecialAirS_figatree	0	7	Kirby	true	1	100	nil	nil	nil	nil	nil	nil	nil	nil	nil	nil	nil	nil	-59	-56
# 10	-56	59	44	40	4	3	normal	3	1	1	323	1.5686274509804	0	0.0	0	0.0	110	0x143	true	69	1.5686274509804	PlyKirby5K_Share_ACTION_SpecialAirS_figatree	0	7	Kirby	true	1	100	nil	nil	nil	nil	nil	nil	nil	nil	nil	nil	nil	nil	-59	-56
# 14	-52	55	44	40	4	3	normal	3	0	2	323	8.2352941176471	0	0.0	0	0.0	110	0x143	true	69	3.1372549019608	PlyKirby5K_Share_ACTION_SpecialAirS_figatree	0	11	Kirby	true	1	100	nil	nil	nil	nil	nil	nil	nil	nil	nil	nil	nil	nil	-55	-52
# */

# %%
from langchain.prompts.prompt import PromptTemplate
from langchain import SQLDatabaseChain
from langchain.callbacks import get_openai_callback

DEFAULT_TEMPLATE = """Given an input question {input}, first create a syntactically correct {dialect} query to run, then look at the results of the query and return the answer.
Use the following format:

Question: "Question here"
SQLQuery: "SQL Query to run"
SQLResult: "Result of the SQLQuery"
Answer: "Final answer here"

Only use the following tables:

{table_info}
"""
PROMPT = PromptTemplate(
    input_variables=["input", "table_info", "dialect"], template=_DEFAULT_TEMPLATE
)

db_chain = SQLDatabaseChain.from_llm(llm, db, prompt=PROMPT, verbose=True, use_query_checker=True)



with get_openai_callback() as cb:
    result = db_chain.run("What is the average weight of all characters?")
    print(cb)
# Out:
# > Entering new  chain...
# What is the average weight of all characters?
# SQLQuery:SELECT AVG(weight) FROM character_attributes;
# SQLResult: [(89.92592592592592,)]
# Answer:Question: What is the average weight of all characters?
# SQLQuery: SELECT AVG(weight) FROM character_attributes;
# > Finished chain.
# Tokens Used: 6600
# 	Prompt Tokens: 6533
# 	Completion Tokens: 67
# Successful Requests: 3
# Total Cost (USD): $0.132

# %% [markdown]
# That last call was pretty expensive, $0.13 for one query because it sent the whole database in.
# Wonder if it'd be possible to use an open-source model and fine-tune it on the db.
#
# Below I'll run a query that will be VERY slow on the first run. Likely when switching this over to production would want to put the loading of the model
# into one function and query calls in another. Larger the model, much longer it takes to load. I've heard flan-t5-xl is somewhat decent to work with.

# %%
## Still expensive.. let's try with an open source model from HuggingFace Hub
# I'm getting time-out errors, will try again with a different model.

import os
HUGGINGFACEHUB_API_TOKEN = os.environ.get('HUGGINGFACEHUB_API_TOKEN')

from langchain import HuggingFaceHub

repo_id = "google/flan-t5-xl" 

llm_flan = HuggingFaceHub(repo_id=repo_id, model_kwargs={"temperature": 0.1}, huggingfacehub_api_token=HUGGINGFACEHUB_API_TOKEN)

db_chain_flan = SQLDatabaseChain.from_llm(llm_flan, db, prompt=PROMPT, verbose=True, use_query_checker=True)
with get_openai_callback() as cb:
    result = db_chain_flan.run("What is the average weight of all characters?")
    print(cb)
# Out:
# > Entering new  chain...
# What is the average weight of all characters?
# SQLQuery:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 14
#      12 db_chain_flan = SQLDatabaseChain.from_llm(llm_flan, db, prompt=PROMPT, verbose=True, use_query_checker=True)
#      13 with get_openai_callback() as cb:
# ---> 14     result = db_chain_flan.run("What is the average weight of all characters?")
#      15     print(cb)
#
# File c:\Users\mrmik\Dropbox (University of Michigan)\github\mi-melee-data\venv\lib\site-packages\langchain\chains\base.py:273, in Chain.run(self, callbacks, tags, *args, **kwargs)
#     271     if len(args) != 1:
#     272         raise ValueError("`run` supports only one positional argument.")
# --> 273     return self(args[0], callbacks=callbacks, tags=tags)[_output_key]
#     275 if kwargs and not args:
#     276     return self(kwargs, callbacks=callbacks, tags=tags)[_output_key]
#
# File c:\Users\mrmik\Dropbox (University of Michigan)\github\mi-melee-data\venv\lib\site-packages\langchain\chains\base.py:149, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, include_run_info)
#     147 except (KeyboardInterrupt, Exception) as e:
#     148     run_manager.on_chain_error(e)
# --> 149     raise e
#     150 run_manager.on_chain_end(outputs)
#     151 final_outputs: Dict[str, Any] = self.prep_outputs(
#     152     inputs, outputs, return_only_outputs
#     153 )
#
# File c:\Users\mrmik\Dropbox (University of Michigan)\github\mi-melee-data\venv\lib\site-packages\langchain\chains\base.py:143, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, include_run_info)
#     137 run_manager = callback_manager.on_chain_start(
#     138     dumpd(self),
#     139     inputs,
#     140 )
#     141 try:
#     142     outputs = (
# --> 143         self._call(inputs, run_manager=run_manager)
#     144         if new_arg_supported
#     145         else self._call(inputs)
#     146     )
#     147 except (KeyboardInterrupt, Exception) as e:
#     148     run_manager.on_chain_error(e)
#
# File c:\Users\mrmik\Dropbox (University of Michigan)\github\mi-melee-data\venv\lib\site-packages\langchain\chains\sql_database\base.py:181, in SQLDatabaseChain._call(self, inputs, run_manager)
#     177 except Exception as exc:
#     178     # Append intermediate steps to exception, to aid in logging and later
#     179     # improvement of few shot prompt seeds
#     180     exc.intermediate_steps = intermediate_steps  # type: ignore
# --> 181     raise exc
#
# File c:\Users\mrmik\Dropbox (University of Michigan)\github\mi-melee-data\venv\lib\site-packages\langchain\chains\sql_database\base.py:116, in SQLDatabaseChain._call(self, inputs, run_manager)
#     114 try:
#     115     intermediate_steps.append(llm_inputs)  # input: sql generation
# --> 116     sql_cmd = self.llm_chain.predict(
#     117         callbacks=_run_manager.get_child(),
#     118         **llm_inputs,
#     119     ).strip()
#     120     if not self.use_query_checker:
#     121         _run_manager.on_text(sql_cmd, color="green", verbose=self.verbose)
#
# File c:\Users\mrmik\Dropbox (University of Michigan)\github\mi-melee-data\venv\lib\site-packages\langchain\chains\llm.py:252, in LLMChain.predict(self, callbacks, **kwargs)
#     237 def predict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#     238     """Format prompt with kwargs and pass to LLM.
#     239
#     240     Args:
#    (...)
#     250             completion = llm.predict(adjective="funny")
#     251     """
# --> 252     return self(kwargs, callbacks=callbacks)[self.output_key]
#
# File c:\Users\mrmik\Dropbox (University of Michigan)\github\mi-melee-data\venv\lib\site-packages\langchain\chains\base.py:149, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, include_run_info)
#     147 except (KeyboardInterrupt, Exception) as e:
#     148     run_manager.on_chain_error(e)
# --> 149     raise e
#     150 run_manager.on_chain_end(outputs)
#     151 final_outputs: Dict[str, Any] = self.prep_outputs(
#     152     inputs, outputs, return_only_outputs
#     153 )
#
# File c:\Users\mrmik\Dropbox (University of Michigan)\github\mi-melee-data\venv\lib\site-packages\langchain\chains\base.py:143, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, include_run_info)
#     137 run_manager = callback_manager.on_chain_start(
#     138     dumpd(self),
#     139     inputs,
#     140 )
#     141 try:
#     142     outputs = (
# --> 143         self._call(inputs, run_manager=run_manager)
#     144         if new_arg_supported
#     145         else self._call(inputs)
#     146     )
#     147 except (KeyboardInterrupt, Exception) as e:
#     148     run_manager.on_chain_error(e)
#
# File c:\Users\mrmik\Dropbox (University of Michigan)\github\mi-melee-data\venv\lib\site-packages\langchain\chains\llm.py:92, in LLMChain._call(self, inputs, run_manager)
#      87 def _call(
#      88     self,
#      89     inputs: Dict[str, Any],
#      90     run_manager: Optional[CallbackManagerForChainRun] = None,
#      91 ) -> Dict[str, str]:
# ---> 92     response = self.generate([inputs], run_manager=run_manager)
#      93     return self.create_outputs(response)[0]
#
# File c:\Users\mrmik\Dropbox (University of Michigan)\github\mi-melee-data\venv\lib\site-packages\langchain\chains\llm.py:102, in LLMChain.generate(self, input_list, run_manager)
#     100 """Generate LLM result from inputs."""
#     101 prompts, stop = self.prep_prompts(input_list, run_manager=run_manager)
# --> 102 return self.llm.generate_prompt(
#     103     prompts,
#     104     stop,
#     105     callbacks=run_manager.get_child() if run_manager else None,
#     106     **self.llm_kwargs,
#     107 )
#
# File c:\Users\mrmik\Dropbox (University of Michigan)\github\mi-melee-data\venv\lib\site-packages\langchain\llms\base.py:140, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     132 def generate_prompt(
#     133     self,
#     134     prompts: List[PromptValue],
#    (...)
#     137     **kwargs: Any,
#     138 ) -> LLMResult:
#     139     prompt_strings = [p.to_string() for p in prompts]
# --> 140     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\mrmik\Dropbox (University of Michigan)\github\mi-melee-data\venv\lib\site-packages\langchain\llms\base.py:206, in BaseLLM.generate(self, prompts, stop, callbacks, tags, **kwargs)
#     204 except (KeyboardInterrupt, Exception) as e:
#     205     run_manager.on_llm_error(e)
# --> 206     raise e
#     207 run_manager.on_llm_end(output)
#     208 if run_manager:
#
# File c:\Users\mrmik\Dropbox (University of Michigan)\github\mi-melee-data\venv\lib\site-packages\langchain\llms\base.py:198, in BaseLLM.generate(self, prompts, stop, callbacks, tags, **kwargs)
#     193 run_manager = callback_manager.on_llm_start(
#     194     dumpd(self), prompts, invocation_params=params, options=options
#     195 )
#     196 try:
#     197     output = (
# --> 198         self._generate(
#     199             prompts, stop=stop, run_manager=run_manager, **kwargs
#     200         )
#     201         if new_arg_supported
#     202         else self._generate(prompts, stop=stop, **kwargs)
#     203     )
#     204 except (KeyboardInterrupt, Exception) as e:
#     205     run_manager.on_llm_error(e)
#
# File c:\Users\mrmik\Dropbox (University of Michigan)\github\mi-melee-data\venv\lib\site-packages\langchain\llms\base.py:498, in LLM._generate(self, prompts, stop, run_manager, **kwargs)
#     495 new_arg_supported = inspect.signature(self._call).parameters.get("run_manager")
#     496 for prompt in prompts:
#     497     text = (
# --> 498         self._call(prompt, stop=stop, run_manager=run_manager, **kwargs)
#     499         if new_arg_supported
#     500         else self._call(prompt, stop=stop, **kwargs)
#     501     )
#     502     generations.append([Generation(text=text)])
#     503 return LLMResult(generations=generations)
#
# File c:\Users\mrmik\Dropbox (University of Michigan)\github\mi-melee-data\venv\lib\site-packages\langchain\llms\huggingface_hub.py:114, in HuggingFaceHub._call(self, prompt, stop, run_manager, **kwargs)
#     112 response = self.client(inputs=prompt, params=params)
#     113 if "error" in response:
# --> 114     raise ValueError(f"Error raised by inference API: {response['error']}")
#     115 if self.client.task == "text-generation":
#     116     # Text generation return includes the starter text.
#     117     text = response[0]["generated_text"][len(prompt) :]
#
# ValueError: Error raised by inference API: Model google/flan-t5-xl time out
